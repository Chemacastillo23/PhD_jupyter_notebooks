# %%
import matplotlib.pyplot as plt
import pandas as pd

df=pd.DataFrame({
    'Program':['First SCF Walltime Transiesta','Total CPU time','siesta','ts_se','IterGeom','IterSCF','ts'],
    '16 MPI':[2.675,308.177,308.107,13.953,292.906,264.398,208.249],
    '32 MPI':[2.009,570.433,570.305,11.09,557.993,535.776,436.80],
    '1 MPI 16 threads':[26.047,2533.657,2533.575,151.023,2381.429,2267.657,2081.998],
    '1 MPI 16 threads bind':[25.953,2525.452,2525.485,150.862,2373.445,2259.736,2076.705],
    '16 MPI 2 threads':[6.709,1195.362,1195.211,26.978,1166.825,1134.77,922.603],
    '16 MPI 2 threads bind':[6.628,1187.585,1195.211,26.99,1159.047,1127.228,916.529],
    '8 MPI 4 threads':[3.961,444.863,444.835,22.019,421.634,386.68,308.175],
    '8 MPI 4 threads bind':[3.969,464.713,464.629,22.047,441.479,406.708,324.53],
    '4 MPI 8 threads':[7.047,973.28,973.224,40.14,931.939,884.826,753.637],
    '4 MPI 8 threads bind':[7.046,971.121,971.134,39.976,930.015,883.281,752.546]
})

# %%
df.plot(kind='bar',x=['Program'],y=['16 MPI','32 MPI','1 MPI 16 threads','16 MPI 2 threads','8 MPI 4 threads','4 MPI 8 threads'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-cb7b8b8be9d8> in <module>
# ----> 1 df.plot(kind='bar',x=['Program'],y=['16 MPI','32 MPI','1 MPI 16 threads','16 MPI 2 threads','8 MPI 4 threads','4 MPI 8 threads'])
#
# ~/.local/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     919                     x = data_cols[x]
#     920                 elif not isinstance(data[x], ABCSeries):
# --> 921                     raise ValueError("x must be a label or position")
#     922                 data = data.set_index(x)
#     923             if y is not None:
#
# ValueError: x must be a label or position

# %%
df.plot(kind='bar',x='Program',y=['16 MPI','32 MPI','1 MPI 16 threads','1 MPI 16 threads bind','16 MPI 2 threads','16 MPI 2 threads bind','8 MPI 4 threads','8 MPI 4 threads bind','4 MPI 8 threads','4 MPI 8 threads bind'],label=False)
# Out:
# <AxesSubplot:xlabel='Program'>

# %%
df2=pd.DataFrame({
    'Program':['First SCF Walltime Transiesta','Total CPU time','siesta','ts_se','IterGeom','IterSCF','ts'],
    '64 MPI':[211.258,2459.885,2459.531,678.083,1779.891,1719.033,1702.858],
    '128 MPI':[210.025,2421.237,2420.890,678.452,1740.828,1687.555,1675.764],
    '64 MPI 2 threads':[208.504,2451.714,2451.382,675.635,1774.221,1713.539,1698.724],
    '64 MPI 4 threads':[198.728,2312.892,2312.743,654.265,1656.656,1597.670,1582.809]
})

# %%
df2.plot(kind='bar',x='Program',y=['64 MPI','128 MPI'])
# Out:
# <AxesSubplot:xlabel='Program'>

# %%
df2.plot(kind='bar',x='Program',y=['64 MPI','64 MPI 2 threads','64 MPI 4 threads','128 MPI'])
# Out:
# <AxesSubplot:xlabel='Program'>
